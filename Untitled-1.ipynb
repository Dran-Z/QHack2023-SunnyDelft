# %%
import numpy as np
import math
from math import pi
import matplotlib.pyplot as plt
# %matplotlib inline

#from scipy.special import iv
#from scipy.linalg import expm, block_diag
#from scipy import integrate
#from openfermion import fermi_hubbard, jordan_wigner, get_sparse_operator
from collections import Counter

from qiskit import QuantumCircuit, QuantumRegister
from qiskit import Aer, transpile
from qiskit.circuit import Parameter
from qiskit import quantum_info as qi
#from qiskit.providers.fake_provider import FakeGuadalupe, FakeNairobi
#from qiskit.visualization import plot_histogram
from scipy.linalg import expm
from HA_utils import Assembly_ACDF, get_real_CDF, get_fh_matrix


import time

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Hamiltonian
#
# $$
# H = (X_1X_2+Y_1Y_2) + (X_3X_4+Y_3Y_4) + 2(Z_1Z_3 + Z_2 Z_4)
# $$

# %%
H = qi.Pauli('XXII').to_matrix() + qi.Pauli('IIXX').to_matrix() + qi.Pauli('YYII').to_matrix() + qi.Pauli('IIYY').to_matrix() + 2*qi.Pauli('ZIZI').to_matrix() + 2*qi.Pauli('IZIZ').to_matrix() 
H = H.real
#print(H)
plt.matshow(H)

# %%
qi.Pauli('YY').to_matrix()
# Out:
# array([[ 0.+0.j,  0.+0.j,  0.+0.j, -1.+0.j],
#        [ 0.+0.j,  0.+0.j,  1.-0.j,  0.+0.j],
#        [ 0.+0.j,  1.-0.j,  0.+0.j,  0.+0.j],
#        [-1.+0.j,  0.+0.j,  0.+0.j,  0.+0.j]])

# %% [markdown]
# If we take the other ordering, where the spin-up and spin-down particle for the same site are placed near each other:

# %%
H = qi.Pauli('XIXI').to_matrix() + qi.Pauli('IXIX').to_matrix() + qi.Pauli('YIYI').to_matrix() + qi.Pauli('IYIY').to_matrix() + 2*qi.Pauli('ZZII').to_matrix() + 2*qi.Pauli('IIZZ').to_matrix() 
plt.matshow(H.real)

# %%
H_fh = get_fh_matrix(N_sites=2, t=1, U=4)
plt.matshow(H_fh)
